# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ##### Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
from matplotlib.animation import FuncAnimation

# %% [markdown]
# ##### Import dataset

# %%
ds = "../datasets/multipleLinearRegression.csv"
data = pd.read_csv(ds)
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# ##### One-hot encode the categorical variables

# %%
data = pd.get_dummies(data, columns=['sex','smoker','region'],drop_first=True, dtype=int)
data = data.dropna()
data
# Out:
#       age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0      19  27.9         0  16884.92         0           1                 0
# 1      18  33.8         1   1725.55         1           0                 0
# 2      28  33.0         3   4449.46         1           0                 0
# 3      33  22.7         0  21984.47         1           0                 1
# 4      32  28.9         0   3866.86         1           0                 1
# ...   ...   ...       ...       ...       ...         ...               ...
# 1333   50  31.0         3  10600.55         1           0                 1
# 1334   18  31.9         0   2205.98         0           0                 0
# 1335   18  36.9         0   1629.83         0           0                 0
# 1336   21  25.8         0   2007.95         0           0                 0
# 1337   61  29.1         0  29141.36         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    0                 0
# 4                    0                 0
# ...                ...               ...
# 1333                 0                 0
# 1334                 0                 0
# 1335                 1                 0
# 1336                 0                 1
# 1337                 0                 0
#
# [1338 rows x 9 columns]

# %% [markdown]
# ##### Split the dataset

# %%
X_train = np.array(data.loc[0:1070,data.columns!='expenses']).reshape(1070,1)
X_train
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_10968/3836414198.py in <module>
# ----> 1 X_train = np.array(data.loc[0:1070,data.columns!='expenses']).reshape(1070,1)
#       2 X_train
#
# ValueError: cannot reshape array of size 8568 into shape (1070,1)
